# %% [markdown]
# <a href="https://colab.research.google.com/github/Mugetsu-Nuckie/dzstatprac/blob/main/1_pythondomashka.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework

# %% [markdown]
# ## Problem 1

# %% [markdown]
# Make a tuple containing natural numbers, the square of which is a multiple of 3, 4, but not a multiple of 8 and not exceeding 12345.

# %%
nums = list(range(12346))
even_squares = [x ** 2 for x in nums if x % 12 == 0 and x % 8 != 0]
print(even_squares)
print(len(even_squares))
# Out:
# [144, 1296, 3600, 7056, 11664, 17424, 24336, 32400, 41616, 51984, 63504, 76176, 90000, 104976, 121104, 138384, 156816, 176400, 197136, 219024, 242064, 266256, 291600, 318096, 345744, 374544, 404496, 435600, 467856, 501264, 535824, 571536, 608400, 646416, 685584, 725904, 767376, 810000, 853776, 898704, 944784, 992016, 1040400, 1089936, 1140624, 1192464, 1245456, 1299600, 1354896, 1411344, 1468944, 1527696, 1587600, 1648656, 1710864, 1774224, 1838736, 1904400, 1971216, 2039184, 2108304, 2178576, 2250000, 2322576, 2396304, 2471184, 2547216, 2624400, 2702736, 2782224, 2862864, 2944656, 3027600, 3111696, 3196944, 3283344, 3370896, 3459600, 3549456, 3640464, 3732624, 3825936, 3920400, 4016016, 4112784, 4210704, 4309776, 4410000, 4511376, 4613904, 4717584, 4822416, 4928400, 5035536, 5143824, 5253264, 5363856, 5475600, 5588496, 5702544, 5817744, 5934096, 6051600, 6170256, 6290064, 6411024, 6533136, 6656400, 6780816, 6906384, 7033104, 7160976, 7290000, 7420176, 7551504, 7683984, 7817616, 7952
# ...

# %% [markdown]
# ## Problem 2

# %% [markdown]
# Write a function that takes a two-dimensional array and a string as input and returns an array rotated 90 degrees counterclockwise if the string 'left' was passed, and clockwise if the string 'right' was passed.
#
# Example for input: $\begin{bmatrix} 1 & 2 & 3 \\ 4 & 5 & 6 \\ 7 & 8 & 9 \end{bmatrix}$.\
# If the string 'left' is passed, the function should return $\begin{bmatrix} 3 & 6 & 9 \\ 2 & 5 & 8 \\ 1 & 4 & 7 \end{bmatrix}$, and if the string 'right' is passed, the function should return $\begin{bmatrix} 7 & 4 & 1 \\ 8 & 5 & 2 \\ 9 & 6 & 3 \end{bmatrix}$.
#
# Do not use numpy and nested loops. Use list comprehensions and built-in function `zip`.

# %%
def rotate(matrix, where):
  if where == 'right' :
     return [list(row)[::-1] for row in zip(*matrix)]
  elif where == 'left' :
     return [list(row) for row in zip(*matrix)][::-1]
  else:
     return matrix

matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
print(rotate(matrix, 'right'))

print(rotate(matrix, 'left'))
# Out:
# [[7, 4, 1], [8, 5, 2], [9, 6, 3]]
# [[3, 6, 9], [2, 5, 8], [1, 4, 7]]

# %% [markdown]
# ## Problem 3

# %% [markdown]
# Write a function that takes a string as input and returns a dictionary containing the number of occurrences of each character in the string. Use method `count` of strings. Implement this function in one line using $\lambda$-function.
#
# Example for the string 'hello, world!': {'h': 1, 'e': 1, 'l': 3, 'o': 2, ',': 1, ' ': 1, 'w': 1, 'r': 1, 'd': 1, '!': 1}.

# %%
count_l= lambda slovo: {simvol: slovo.count(simvol) for simvol in slovo}
string = 'hello, world!'
print(count_l(string))
# Out:
# {'h': 1, 'e': 1, 'l': 3, 'o': 2, ',': 1, ' ': 1, 'w': 1, 'r': 1, 'd': 1, '!': 1}

# %% [markdown]
# ## Problem 4

# %% [markdown]
# ### Implementing a Library Management System
#
# #### Description
#
# You are required to design and implement a system for managing books and users in a library. The system should allow for the management of books (adding, deleting, searching by various criteria) and users (registration, deletion, searching), as well as tracking the history of interactions between them (issuing and returning books).
#
# #### Tasks
#
# 1. **`Book` Class**:
#    - Attributes: title, author, year of publication, ISBN, number of copies.
#    - Methods: constructor, methods to get information about the book, method to change the number of copies (when issuing and returning books).
#
# 2. **`User` Class**:
#    - Attributes: user name, library card number, list of borrowed books.
#    - Methods: constructor, methods for user registration, methods for adding and removing books from the borrowed list.
#
# 3. **`Library` Class**:
#    - Attributes: list of books, list of users, transaction history (who, when, which book was borrowed and returned).
#    - Methods: constructor, methods for adding and deleting books and users, methods for issuing and returning books, searching for books and users by various criteria, method to display the transaction history.
#
# #### Assignment
#
# 1. Implement the `Book`, `User`, and `Library` classes with the specified attributes and methods.
# 2. Create several books and users, and add them to the library system.
# 3. Implement scenarios for issuing books to users and their return.
# 4. Display the transaction history to show how books were issued and returned.

# %%
class Book:
    def __init__(self, title, author, year, isbn, copies):
        self.title = title
        self.author = author
        self.year = year
        self.isbn = isbn
        self.copies = copies
        print(f"Book '{title}' created")

    def get_info(self):
        return f"{self.title} by {self.author} ({self.year}) | ISBN: {self.isbn} | Copies available: {self.copies}"

    def change_copies(self, amount):
        self.copies += amount
        print(f"Copies of '{self.title}' updated. Now available: {self.copies}")


class User:
    def __init__(self, name, card_number):
        self.name = name
        self.card_number = card_number
        self.borrowed_books = []
        print(f"User {name} registered")

    def borrow_book(self, book):
        if book.copies > 0 and book not in self.borrowed_books:
            book.change_copies(-1)
            self.borrowed_books.append(book)
            print(f"{self.name} borrowed '{book.title}'")
            return True
        print(f"Borrowing failed for '{book.title}'")
        return False

    def return_book(self, book):
        if book in self.borrowed_books:
            book.change_copies(1)
            self.borrowed_books.remove(book)
            print(f"{self.name} returned '{book.title}'")
            return True
        print(f"Return failed. '{book.title}' not borrowed by {self.name}")
        return False

    def list_borrowed_books(self):
        return [book.get_info() for book in self.borrowed_books]


class Library:
    def __init__(self):
        self.books = []
        self.users = []
        self.transaction_history = []
        print("Library system created")

    def add_book(self, book):
        self.books.append(book)

    def remove_book(self, book):
        if book in self.books:
            self.books.remove(book)

    def register_user(self, user):
        self.users.append(user)

    def remove_user(self, user):
        if user in self.users:
            self.users.remove(user)

    def issue_book(self, user, book):
        if user.borrow_book(book):
            self.transaction_history.append(f"{user.name} borrowed '{book.title}'")
            return True
        return False

    def return_book(self, user, book):
        if user.return_book(book):
            self.transaction_history.append(f"{user.name} returned '{book.title}'")
            return True
        return False

    def search_book_by_title(self, title):
        return [book.get_info() for book in self.books if title.lower() in book.title.lower()]

    def search_user_by_name(self, name):
        return [user.name for user in self.users if name.lower() in user.name.lower()]

    def display_transaction_history(self):
        for record in self.transaction_history:
            print(record)


# Example usage
library = Library()

# Creating books
book1 = Book("Денискины рассказы", "Виктор Драгунский", 1949, "1234567890", 3)
library.add_book(book1)

# Registering users
user1 = User("Алиса Гранкина", "L1001")
library.register_user(user1)

# Issuing book
library.issue_book(user1, book1)

# Returning book
library.return_book(user1, book1)

# Displaying transaction history
library.display_transaction_history()
# Out:
# Library system created
# Book 'Денискины рассказы' created
# User Алиса Гранкина registered
# Copies of 'Денискины рассказы' updated. Now available: 2
# Алиса Гранкина borrowed 'Денискины рассказы'
# Copies of 'Денискины рассказы' updated. Now available: 3
# Алиса Гранкина returned 'Денискины рассказы'
# Алиса Гранкина borrowed 'Денискины рассказы'
# Алиса Гранкина returned 'Денискины рассказы'

# %% [markdown]
# ## Problem 5*

# %% [markdown]
# Explain why list `b` changes after the execution of the following code:
#
# ```python
# a = [1, 2, 3]
# b = a
# a[0] = 4
# print(b)
# ```

# %% [markdown]
#  > Write your answer in markdown cell after: Как я понимаю, в строчке b=a мы копируем просто содержание а, а не создаем новый список b совпадающий с а. ПОЭТОМУ при изменении а и выводе b, мы по сути выводим копию измененного а. Вот так.

# %% [markdown]
# ## Problem 6*

# %% [markdown]
# Let
# $$A = \sum_{i=1}^{10000} \frac{1}{i^2},\quad B=\sum_{i=10000}^{1} \frac{1}{i^2}.$$
# Calculate the values of $A$ and $B$ and compare them. What do you observe? Explain why this happens. What is the best way to calculate the value of $\sum\limits_{i=1}^{10000} \dfrac{1}{i^2}$?

# %%
A = 0.0
for i in range(1, 10001, 1):
    A += 1 / (i * i)
B = 0.0
for i in range(10000, 0, -1):
    B += 1 / (i * i)

print("A =", A)
print("B =", B)
print("B-A", B - A)
#такая нестыковка происходит из-за того, что при посчете А, посчет начинается с больших к котором затем плюсуются маленькие и из за точности округления и тп теряются некоторые значения, потому что если к большому прибавляется очеень маленькое он его не видит.
#а в B сначала складываются очень маленькие и как снежный ком превращаются в большое и в конце складываются больше поэтому там этой потери нет, получается что лучший способ складывать такие числа, идти от сложения самых маленьких к самым большим тогда потерь не будет
# Out:
# A = 1.6448340718480652
# B = 1.6448340718480596
# B-A -5.551115123125783e-15
